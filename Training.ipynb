# %%
# !git clone https://github.com/saied-salem/3D-Nudel-CT-Classification.git
# Out:
# Cloning into '3D-Nudel-CT-Classification'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 49 (delta 26), reused 34 (delta 14), pack-reused 0
# Receiving objects: 100% (49/49), 13.07 KiB | 13.07 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
# %cd /content/3D-Nudel-CT-Classification
# Out:
# /content/3D-Nudel-CT-Classification

# %%
# !pip install medmnist
# !pip install wandb
# !pip install -q "monai[tqdm]"
# !pip install torcheval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116933 sha256=adc5b42be35d24c319a851e94f6cfb742bcde5f49b3e4ae005e02c5a72b08667
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.6/248.6 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 2.5 MB/s eta 0:00:00
# ...

# %%
! wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## For Sweep controller machine only

# %%
# !wandb sweep -e saied-salem -p  NoduleMNIST sweep.yaml
# Out:
# wandb: Creating sweep from: sweep.yaml
# wandb: Creating sweep with ID: pbi2hwcj
# wandb: View sweep at: https://wandb.ai/saied-salem/NoduleMNIST/sweeps/pbi2hwcj
# wandb: Run sweep agent with: wandb agent saied-salem/NoduleMNIST/pbi2hwcj

# %% [markdown]
# ## For Sweep agents

# %%
# !wandb agent saied-salem/NoduleMNIST/pbi2hwcj --count 35
# Out:
# wandb: Starting wandb agent 🕵️
# 2023-11-14 17:09:32,120 - wandb.wandb_agent - INFO - Running runs: []
# 2023-11-14 17:09:32,449 - wandb.wandb_agent - INFO - Agent received command: run
# 2023-11-14 17:09:32,449 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	arch: resnet34
# 	augment: true
# 	batch_size: 145
# 	lr: 0.00284639031520774
# 	optimizer: SGD
# 	weight_decay: 0.0007116703060793435
# 	weighted_loss: true
# 2023-11-14 17:09:32,451 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python Run.py --arch=resnet34 --augment=true --batch_size=145 --lr=0.00284639031520774 --optimizer=SGD --weight_decay=0.0007116703060793435 --weighted_loss=true
# 2023-11-14 17:09:37,460 - wandb.wandb_agent - INFO - Running runs: ['hrk2rxcn']
# 2023-11-14 17:09:37.508609: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# # Training using insights from hyper parameter seach

# %%
# !python Run.py
# Out:
# 2023-11-15 03:34:58.324194: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-15 03:34:58.324251: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-15 03:34:58.324302: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-15 03:34:58.332328: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## Sweep link: https://wandb.ai/saied-salem/NoduleMNIST/sweeps/pbi2hwcj?workspace=user-saied-salem
