# %%
# !git clone https://github.com/saied-salem/3D-Nudel-CT-Classification.git
# Out:
# Cloning into '3D-Nudel-CT-Classification'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 55 (delta 30), reused 38 (delta 16), pack-reused 0
# Receiving objects: 100% (55/55), 13.79 KiB | 6.90 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# !pip install medmnist
# !pip install wandb
# !pip install -q "monai[tqdm]"
# !pip install gdown
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116933 sha256=7596e6521580c74a32194167a3f18e15bcbac56549038a211dd1df8be6113ad2
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.6/248.6 kB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Online Evlaution only

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python "/content/3D-Nudel-CT-Classification/evaluate.py" --model_name 'SEResNet50:v7'
# Out:
# 2023-11-15 14:06:39.105586: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-15 14:06:39.105680: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-15 14:06:39.105728: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-15 14:06:39.116077: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # Final reults organized: https://wandb.ai/saied-salem/NoduleMNIST/runs/kwy7czp9?workspace=user-saied-salem

# %% [markdown]
# # Offline Evlaution only

# %%
# !gdown  -O /content/artifacts.zip  "https://drive.google.com/uc?id=1-DMJgmTuR-lwbALxk8s9fQW-hg-JdL87"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-DMJgmTuR-lwbALxk8s9fQW-hg-JdL87
# To: /content/artifacts.zip
# 100% 181M/181M [00:01<00:00, 167MB/s]

# %%
import shutil

zip_file_path = '/content/artifacts.zip'
destination_dir = '/content/artifacts'
shutil.unpack_archive(zip_file_path, destination_dir)

# %%
# !python "/content/3D-Nudel-CT-Classification/evaluate.py"  --offline_mode True
# Out:
# 2023-11-15 14:12:13.060440: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-15 14:12:13.060522: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-15 14:12:13.060604: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-15 14:12:13.077037: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # Final reults organized: https://wandb.ai/saied-salem/Testing_NoduleMNIST/runs/6h1q614u?workspace=user-saied-salem
